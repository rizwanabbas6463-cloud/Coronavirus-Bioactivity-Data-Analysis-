# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwanabbas6463-cloud/Coronavirus-Bioactivity-Data-Analysis-/blob/main/CDD_ML_Part_10_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# ...

# %%
selected_target = targets.target_chembl_id[6]
selected_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      1480935                  []
# 1        None             None      1480936                  []
# 2        None             None      1481061                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 1    CHEMBL829584  In vitro inhibitory concentration against SARS...
# 2    CHEMBL830868  In vitro inhibitory concentration against SARS...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                                      target_organism  \
# 0  Severe acute respiratory syndrome-related coro...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 138803 Sep  1 10:41 '/content/gdrive/My Drive/Colab Notebooks/data'

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 242  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 243  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 244  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 245  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 246  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 242    CHEMBL4590273
# 243    CHEMBL5436771
# 244    CHEMBL2365410
# 245    CHEMBL5436771
# 246    CHEMBL2365410
# Name: molecule_chembl_id, Length: 245, dtype: object

# %% [markdown]
# Data pre-processing of the bioactivity data

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Alternative method

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 242      CHEMBL4590273                  Cc1cccc2nc(CSC(=S)NCc3cccnc3)cn12
# 243      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 244      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 245      CHEMBL5436771                           S=C([S-])NCc1cccnc1.[K+]
# 246      CHEMBL2365410  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC1C...
# 220                NaN                                                NaN
# 222                NaN                                                NaN
#
#     standard_value             0
# 0           7200.0  intermediate
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 164
# -rw-r--r-- 1 root root 138803 Sep  1 10:40 bioactivity_data.csv
# -rw-r--r-- 1 root root  18356 Sep  1 10:52 bioactivity_preprocessed_data.csv
# drwx------ 5 root root   4096 Sep  1 10:41 gdrive
# drwxr-xr-x 1 root root   4096 Aug 28 13:43 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# bioactivity_data.csv  bioactivity_preprocessed_data.csv yh output ani chyeaye hy .

# %% [markdown]
# Setting up: You started by installing a tool called chembl_webresource_client which helps you get information about chemicals and their biological activities from a database called ChEMBL.
# Connecting and Searching: You then used this tool to connect to the ChEMBL database and searched for information related to "coronavirus". This gave you a list of targets related to coronavirus.
# Selecting a Target: From the list of targets, you selected a specific one, CHEMBL3927, which is the SARS coronavirus 3C-like proteinase. This is a protein in the virus that is important for its function.
# Getting Activity Data: You then retrieved data on the biological activity of different molecules against this specific protein target. You filtered this data to include only results measured using a standard method called "IC50".
# Putting Data in a Table: You organized the retrieved data into a table called a DataFrame, which is a standard way to handle data in Python.
# Checking and Cleaning Data: You checked the data to see which molecules had activity information (standard_value).
# Categorizing Activity: You classified the molecules into three categories based on their activity (active, intermediate, or inactive) using the standard_value.
# Selecting Important Columns: You created a new table with only the most important information: the molecule ID, its chemical structure representation (canonical_smiles), and its activity value (standard_value).
# Combining and Saving: You combined the selected columns with the bioactivity classes you created and saved this processed data to a CSV file named bioactivity_preprocessed_data.csv.
# Saving to Google Drive: Finally, you saved the original and preprocessed data files to your Google Drive for safekeeping and future use.
# Essentially, you've found molecules that might be effective against a key protein in the SARS coronavirus, categorized their effectiveness, and saved this information for further analysis.
